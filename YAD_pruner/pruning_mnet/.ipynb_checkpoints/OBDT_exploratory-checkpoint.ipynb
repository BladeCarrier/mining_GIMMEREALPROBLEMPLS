# %%
# I explore the cuts of the features

# %%
# %matplotlib inline
#так тоже можно решить проблему инлайла плотов

# %%
import _matrixnetapplier as mnet
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

# %%
#extract ODT
fstream = open('formula.mx','rb')
classi = mnet.MatrixnetClassifier(fstream)
fstream.close()

# %%
#Get all the trees from .mx
def get_trees(classi):
    itr = classi.iterate_trees().next()
    return itr, [tree for tree in itr[2]]

# %%
itr,trees = get_trees(classi)
n_features = len(classi.features)

# %%
#cut histogram visualization
cuts = lambda feature: reduce(np.append,[tree[1][tree[0] == feature] for tree in  trees])
def hist(feature,bins = 100):
    plt.legend(handles = [mpatches.Patch(label="feature" + str(feature))])
    plt.hist(cuts(feature),bins = bins)
    plt.show();

# %%
def get_best(feature,tolerance=0.):
    thresholds = cuts(feature)
    tolerance *= np.var(thresholds)
    thrs = { threshold: len(filter(
                                lambda thr: abs(thr - threshold) <= tolerance,
                                thresholds)
                           )
            for threshold in set(thresholds)}
    return thrs

# %%
best = {i:get_best(i,0.001) for i in range(30)}

# %%
#usability distribution
thresholds = reduce(np.append,[zip(np.repeat(i,len(best[i])),best[i].keys(),best[i].values()) for i in best])
thresholds = thresholds.reshape(thresholds.shape[0]/3,3)

plt.scatter(range(len(thresholds)),thresholds[:,2])
print sum(thresholds[:,2] >400)
# Out:
# 8

# %%
# Out:
# (1982, 3)

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-89-aceb403cf305> in <module>()
# ----> 1 zz =np.ndarray(zip(np.repeat(i,len(best[i])),best[i].keys(),best[i].values()))
#
# ValueError: sequence too large; must be smaller than 32

# %%
# Out:
# array([[  93.27000427,  429.        ],
#        [  86.70149994,  424.        ],
#        [ 120.68599701,  379.        ],
#        ...,
#        [  52.20249939,   23.        ],
#        [ 176.22799683,   14.        ],
#        [ 139.01750183,    4.        ]])

# %% [markdown]
# Давайте залипать на гисты...

# %%
for f in range(n_features): hist(f);

# %%
#for f in range(n_features): hist(f,1000);

# %% [markdown]
# # Визуализация буста

# %%
from sklearn.manifold import TSNE
import pandas as pd
from sklearn.decomposition import TruncatedSVD

# %%
feature_usage = pd.DataFrame({i: xrange(n_features) for i in range(len(trees))})
for i in xrange(len(trees)):
    tree_feats = set(trees[i][0])
    tree_feats_bin = [int(f in tree_feats) for f in xrange(n_features)]
    feature_usage[i] = tree_feats_bin
feature_usage = feature_usage.transpose()

# %%
feat_trunc = TruncatedSVD(n_components=50, random_state=0).fit_transform(vectors)
feat_tsne = TSNE(learning_rate=100).fit_transform(feat_trunc)

# %%
feat_indices = xrange(0,300)#np.random.choice(xrange(feature_usage.shape[0]),1000)
feat_data = feature_usage.ix[feat_indices,]
feat_tsne = TSNE(learning_rate=100,verbose = 1).fit_transform(feat_data)
#plot against tree id
plt.scatter(feat_tsne[:, 0], feat_tsne[:, 1],c = xrange(len(feat_tsne[:,0])))
# Out:
# [t-SNE] Computing pairwise distances...
# [t-SNE] Computed conditional probabilities for sample 300 / 300
# [t-SNE] Mean sigma: 0.000000
# [t-SNE] Error after 83 iterations with early exaggeration: 11.640395
# [t-SNE] Error after 288 iterations: 0.337968
